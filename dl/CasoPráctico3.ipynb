# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score
from sklearn.datasets import load_digits
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split

# %%
digits_dataset = load_digits()
X = digits_dataset.images
y = digits_dataset.target

# %%
plt.imshow(X[100])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

mlp = MLPClassifier(hidden_layer_sizes=(10,), activation='logistic', solver='sgd')
mlp.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 4
#       1 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
#       3 mlp = MLPClassifier(hidden_layer_sizes=(10,), activation='logistic', solver='sgd')
# ----> 4 mlp.fit(X_train, y_train)
#
# File ~/.local/lib/python3.11/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:753, in BaseMultilayerPerceptron.fit(self, X, y)
#     735 @_fit_context(prefer_skip_nested_validation=True)
#     736 def fit(self, X, y):
#     737     """Fit the model to data matrix X and target(s) y.
#     738
#     739     Parameters
#    (...)
#     751         Returns a trained MLP model.
#     752     """
# --> 753     return self._fit(X, y, incremental=False)
#
# File ~/.local/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:442, in BaseMultilayerPerceptron._fit(self, X, y, incremental)
#     435     raise ValueError(
#     436         "hidden_layer_sizes must be > 0, got %s." % hidden_layer_sizes
#     437     )
#     438 first_pass = not hasattr(self, "coefs_") or (
#     439     not self.warm_start and not incremental
#     440 )
# --> 442 X, y = self._validate_input(X, y, incremental, reset=first_pass)
#     444 n_samples, n_features = X.shape
#     446 # Ensure y is 2D
#
# File ~/.local/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:1093, in MLPClassifier._validate_input(self, X, y, incremental, reset)
#    1092 def _validate_input(self, X, y, incremental, reset):
# -> 1093     X, y = self._validate_data(
#    1094         X,
#    1095         y,
#    1096         accept_sparse=["csr", "csc"],
#    1097         multi_output=True,
#    1098         dtype=(np.float64, np.float32),
#    1099         reset=reset,
#    1100     )
#    1101     if y.ndim == 2 and y.shape[1] == 1:
#    1102         y = column_or_1d(y, warn=True)
#
# File ~/.local/lib/python3.11/site-packages/sklearn/base.py:621, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     619         y = check_array(y, input_name="y", **check_y_params)
#     620     else:
# --> 621         X, y = check_X_y(X, y, **check_params)
#     622     out = X, y
#     624 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/.local/lib/python3.11/site-packages/sklearn/utils/validation.py:1147, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1142         estimator_name = _check_estimator_name(estimator)
#    1143     raise ValueError(
#    1144         f"{estimator_name} requires y to be passed, but the target y is None"
#    1145     )
# -> 1147 X = check_array(
#    1148     X,
#    1149     accept_sparse=accept_sparse,
#    1150     accept_large_sparse=accept_large_sparse,
#    1151     dtype=dtype,
#    1152     order=order,
#    1153     copy=copy,
#    1154     force_all_finite=force_all_finite,
#    1155     ensure_2d=ensure_2d,
#    1156     allow_nd=allow_nd,
#    1157     ensure_min_samples=ensure_min_samples,
#    1158     ensure_min_features=ensure_min_features,
#    1159     estimator=estimator,
#    1160     input_name="X",
#    1161 )
#    1163 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1165 check_consistent_length(X, y)
#
# File ~/.local/lib/python3.11/site-packages/sklearn/utils/validation.py:953, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     948     raise ValueError(
#     949         "dtype='numeric' is not compatible with arrays of bytes/strings."
#     950         "Convert your data to numeric values explicitly instead."
#     951     )
#     952 if not allow_nd and array.ndim >= 3:
# --> 953     raise ValueError(
#     954         "Found array with dim %d. %s expected <= 2."
#     955         % (array.ndim, estimator_name)
#     956     )
#     958 if force_all_finite:
#     959     _assert_all_finite(
#     960         array,
#     961         input_name=input_name,
#     962         estimator_name=estimator_name,
#     963         allow_nan=force_all_finite == "allow-nan",
#     964     )
#
# ValueError: Found array with dim 3. MLPClassifier expected <= 2.
